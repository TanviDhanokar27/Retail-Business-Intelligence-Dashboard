# %% [markdown]
# # Business Insights
#
# The objective of this notebook is to summarize the findings obtained from SQL queries, Python EDA, and Power BI dashboard.

# %% [markdown]
# # Insight 1: Revenue Trend
#
# Observation:
#
# Revenue increased steadily during 2017 and reached its highest level towards the end of the year.
#
# Business Impact:
#
# Growing revenue indicates increasing customer demand and business expansion.
#
# Recommendation:
#
# Maintain marketing efforts during high-performing months and prepare inventory in advance for seasonal demand.

# %% [markdown]
# # Insight 2: Product Categories
#
# Observation:
#
# Health & Beauty products generated the highest revenue followed by Watches & Gifts and Bed Bath Table.
#
# Business Impact:
#
# These categories contribute significantly to overall business revenue.
#
# Recommendation:
#
# Maintain adequate inventory levels and prioritize these categories during promotional campaigns.

# %% [markdown]
# # Insight 3: Customer Distribution
#
# Observation:
#
# São Paulo has the highest number of customers.
#
# Business Impact:
#
# The majority of business revenue is driven by customers from this state.
#
# Recommendation:
#
# Strengthen customer retention in São Paulo while expanding marketing efforts in lower-performing states.

# %% [markdown]
# # Insight 4: Payment Methods
#
# Observation:
#
# Approximately 74% of customers prefer Credit Card payments.
#
# Business Impact:
#
# Customers favor fast and convenient digital payment methods.
#
# Recommendation:
#
# Optimize the credit card payment experience while encouraging adoption of alternative payment methods.

# %% [markdown]
# # Insight 5: Delivery Performance
#
# Observation:
#
# Average delivery time is approximately 13 days.
#
# Business Impact:
#
# Long delivery times may reduce customer satisfaction.
#
# Recommendation:
#
# Improve logistics efficiency and reduce delivery time to enhance customer experience.

# %% [markdown]
# # Insight 6: Customer Reviews
#
# Observation:
#
# Most customers rated their experience as Excellent.
#
# Business Impact:
#
# The company maintains a high level of customer satisfaction.
#
# Recommendation:
#
# Continue maintaining product quality and customer service standards.

# %%
# Insight 7: Delivery Time vs Review Score

Observation:

Customers who experienced longer delivery times generally gave lower review scores.

Business Impact:

Delivery performance directly impacts customer satisfaction.

Recommendation:

Prioritize faster deliveries to improve review scores and customer loyalty.

# %% [markdown]
# # Final Recommendations
#
# 1. Maintain inventory for high-demand product categories.
#
# 2. Improve delivery efficiency to reduce shipping time.
#
# 3. Focus marketing campaigns on high-performing regions while expanding into underperforming states.
#
# 4. Continue supporting Credit Card payments while promoting alternative payment methods.
#
# 5. Use customer review analysis to identify opportunities for service improvement.
#
# 6. Monitor monthly revenue trends for better inventory and sales planning.
#
# 7. Regularly update the Power BI dashboard to support data-driven decision-making.

# %% [markdown]
# # Dashboard
#
# The insights presented in this notebook are visualized through the interactive Power BI dashboard, which includes:
#
# - KPI Cards
# - Revenue Trend
# - Customer Distribution
# - Product Category Analysis
# - Payment Method Distribution
# - Review Category Distribution
# - Delivery Time Analysis
# - Year-wise Filtering
